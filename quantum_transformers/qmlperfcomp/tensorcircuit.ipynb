# %%
import numpy as np
from quantum_transformers.qmlperfcomp.tc_common import get_quantum_layer_circuit
# Out:
# 2023-08-14 10:14:45.335835: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Please first ``pip install -U cirq`` to enable related functionality in translation module

# %%
inputs = np.random.uniform(size=(5,))
weights = np.random.uniform(size=(2, 5))
c = get_quantum_layer_circuit(inputs, weights)
c.draw(output='mpl')

# %%
inputs = np.random.uniform(size=(2,))
weights = np.random.uniform(size=(5, 2))
c = get_quantum_layer_circuit(inputs, weights)
c.draw(output='mpl')

# %%
inputs = np.random.uniform(size=(1,))
weights = np.random.uniform(size=(1, 1))
c = get_quantum_layer_circuit(inputs, weights)
c.draw(output='mpl')
